# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import matplotlib as mpl
import NB_Funcs as hlp
import seaborn as sns

# %%
def pickle_save(filename, data):
    with open(filename,'wb') as _save:
        pickle.dump(data,_save)
    
def pickle_load(filename):
    with open(filename,'rb') as _load:
        var = pickle.load(_load)
    return var

def best_score(model, featureSet):
    model.equations_['feature_set'] = featureSet
    ind = model.equations_['score'].idxmax()
    df = model.equations_.iloc[ind]
    return df

# %% [markdown]
# # $ \frac{dN}{dt\cdot N} = r*S$
#
# # $ \frac{dS}{dt} = -\nu\frac{dN}{dt}+D(\bar{S} - S), (\nu = 2*10^{-7}, D = .1)$

# %%
DIFF_DF = pickle_load("../Pickles/Data/Diffusion_PreprocessedData")
N_D = np.load('../data/October/Diffusion/diffusion_S_n_curves_10_10_2022.npy')
S_D = np.load('../data/October/Diffusion/diffusion_S_s_curves_10_10_2022.npy')

# %% [markdown]
# # Feature Set 1: N

# %%
fs1 = pickle_load("../Scripts/DIFF/DIFF_FS1.pkl"); fs1E = best_score(fs1,1); fs1E['sympy_format']
# Out:
# 0.45493382 - 8.3692264e-8*Pop

# %%
fs1MB = fs1.get_best(); fs1MB['sympy_format']
# Out:
# (1.05545446e-7*Pop - 0.5423351)*(Pop*exp(1.26435654139841e-14*Pop) - Pop - 0.9143719)

# %%
fs1E['features'] = r"$N$"; fs1MB['features'] = r"$N$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/1530177411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs1E['features'] = r"$N$"; fs1MB['features'] = r"$N$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/1530177411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs1E['features'] = r"$N$"; fs1MB['features'] = r"$N$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/1530177411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs1.equations_['complexity'],fs1.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 1 Equations")
axT = ax.twinx()
axT.plot(fs1.equations_['complexity'],fs1.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Feature Set 2: N, Ring

# %%
fs2 = pickle_load("../Scripts/DIFF/DIFF_FS2.pkl"); fs2E = best_score(fs2,2); fs2E['sympy_format']
# Out:
# 0.45494077 - 8.369216e-8*Pop

# %%
fs2MB = fs2.get_best(); fs2MB['sympy_format']
# Out:
# -9.7697765e-8*Pop + 0.4959181 + 3.79971157909288*exp(-20395367.4615*Ring/Pop)

# %%
fs2E['features'] = r"$N$"; fs2MB['features'] = r"$N,Ring$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2917330093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs2E['features'] = r"$N$"; fs2MB['features'] = r"$N,Ring$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2917330093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs2E['features'] = r"$N$"; fs2MB['features'] = r"$N,Ring$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2917330093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs2.equations_['complexity'],fs2.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 2 Equations")
axT = ax.twinx()
axT.plot(fs2.equations_['complexity'],fs2.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Feature Set 3: N, N_0

# %%
fs3 = pickle_load("../Scripts/DIFF/DIFF_FS3.pkl"); fs3E = best_score(fs3,3); fs3E['sympy_format']
# Out:
# 0.4549711 - 8.370009e-8*Pop

# %%
fs3MB = fs3.get_best(); fs3MB['sympy_format']
# Out:
# (0.6220231 - 1.1932663e-7*Pop)*(0.7986057 - 3.63062500447021*exp(-11666997.0528347/Pop))

# %%
fs3E['features'] = r"$N$"; fs3MB['features'] = r"$N$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2030577421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs3E['features'] = r"$N$"; fs3MB['features'] = r"$N$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2030577421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs3E['features'] = r"$N$"; fs3MB['features'] = r"$N$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2030577421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs3.equations_['complexity'],fs3.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 3 Equations")
axT = ax.twinx()
axT.plot(fs3.equations_['complexity'],fs3.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Feature Set 4: N, N_bar

# %%
fs4 = pickle_load("../Scripts/DIFF/DIFF_FS4.pkl"); fs4E = best_score(fs4,4); fs4E['sympy_format']
# Out:
# 0.47292382 - 9.292673e-8*Nbar

# %%
fs4MB = fs4.get_best(); fs4MB['sympy_format']
# Out:
# -7.715307e-8*Pop*(1.2617489 + 5.6233144e-8*Pop*(Nbar - Pop)/Nbar) + 0.4952704

# %%
fs4E['features'] = r"$\bar{N}$"; fs4MB['features'] = r"$N,\bar{N}$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/1848232699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs4E['features'] = r"$\bar{N}$"; fs4MB['features'] = r"$N,\bar{N}$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/1848232699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs4E['features'] = r"$\bar{N}$"; fs4MB['features'] = r"$N,\bar{N}$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/1848232699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs4.equations_['complexity'],fs4.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 4 Equations")
axT = ax.twinx()
axT.plot(fs4.equations_['complexity'],fs4.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Feature Set 5: N, Ring, N_bar

# %%
fs5 = pickle_load("../Scripts/DIFF/DIFF_FS5.pkl"); fs5E = best_score(fs5,5); fs5E['sympy_format']
# Out:
# 0.47291678 - 9.2923784e-8*Nbar

# %%
fs5MB = fs5.get_best(); fs5MB['sympy_format']
# Out:
# -9.798676e-8*Pop - 9.798676e-8*(-Nbar + Pop)*(1.6418585e-7*Nbar - 1.6418585e-7*Pop - 0.059933215*Ring) + 0.49582723

# %%
fs5E['features'] = r"$\bar{N}$"; fs5MB['features'] = r"$N,\bar{N},Ring$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3873067752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs5E['features'] = r"$\bar{N}$"; fs5MB['features'] = r"$N,\bar{N},Ring$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3873067752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs5E['features'] = r"$\bar{N}$"; fs5MB['features'] = r"$N,\bar{N},Ring$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3873067752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs5.equations_['complexity'],fs5.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 5 Equations")
axT = ax.twinx()
axT.plot(fs5.equations_['complexity'],fs5.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Feature Set 9: N_C

# %%
fs9 = pickle_load("../Scripts/DIFF/DIFF_FS9.pkl"); fs9E = best_score(fs9,9); fs9E['sympy_format']
# Out:
# 0.48962718*exp(-9.427608e-8*Cum_N)

# %%
fs9MB = fs9.get_best(); fs9MB['sympy_format']
# Out:
# 0.48962718*exp(-9.427608e-8*Cum_N)

# %%
fs9E['features'] = r"$N_C$"; fs9MB['features'] = r"$N_C$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3842139931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs9E['features'] = r"$N_C$"; fs9MB['features'] = r"$N_C$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3842139931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs9E['features'] = r"$N_C$"; fs9MB['features'] = r"$N_C$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3842139931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs9.equations_['complexity'],fs9.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 9 Equations")
axT = ax.twinx()
axT.plot(fs9.equations_['complexity'],fs9.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Feature Set 10: N_C, N_bar_C

# %%
fs10 = pickle_load("../Scripts/DIFF/DIFF_FS10.pkl"); fs10E = best_score(fs10,10); fs10E['sympy_format']
# Out:
# 0.4896427*exp(-9.429502e-8*Cum_N)

# %%
fs10HP = fs10.get_best(8); fs10HP['sympy_format']
# Out:
# exp(-8.19501244986291*Cum_Nbar/Cum_N) + 0.488222175047167*exp(-9.511543e-8*Cum_N)

# %%
fs10MB = fs10.get_best(); fs10MB['sympy_format']
# Out:
# (0.019496204*Cum_N - 0.019496204*Cum_Nbar)/(Cum_Nbar + 805184.378971702) + 0.489650895480247*exp(-9.511543e-8*Cum_N)

# %%
fs10E['features'] = r"$N_C$"; fs10MB['features'] = r"$N_C,\bar{N}_C$"; fs10HP['features'] = r"$N_C,\bar{N}_C$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/230133679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs10E['features'] = r"$N_C$"; fs10MB['features'] = r"$N_C,\bar{N}_C$"; fs10HP['features'] = r"$N_C,\bar{N}_C$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/230133679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs10E['features'] = r"$N_C$"; fs10MB['features'] = r"$N_C,\bar{N}_C$"; fs10HP['features'] = r"$N_C,\bar{N}_C$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/230133679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs10.equations_['complexity'],fs10.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 10 Equations")
axT = ax.twinx()
axT.plot(fs10.equations_['complexity'],fs10.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Feature Set 11: N_C, N_0

# %%
fs11 = pickle_load("../Scripts/DIFF/DIFF_FS11.pkl"); fs11E = best_score(fs11,11); fs11E['sympy_format']
# Out:
# 0.48963177*exp(-9.428506e-8*Cum_N)

# %%
fs11MB = fs11.get_best(); fs11MB['sympy_format']
# Out:
# 0.48963177*exp(-9.428506e-8*Cum_N)

# %%
fs11E['features'] = r"$N_C$"; fs11MB['features'] = r"$N_C$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3625648044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs11E['features'] = r"$N_C$"; fs11MB['features'] = r"$N_C$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3625648044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs11E['features'] = r"$N_C$"; fs11MB['features'] = r"$N_C$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3625648044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs11.equations_['complexity'],fs11.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 11 Equations")
axT = ax.twinx()
axT.plot(fs11.equations_['complexity'],fs11.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Feature Set 12: N_C, Ring

# %%
fs12 = pickle_load("../Scripts/DIFF/DIFF_FS12.pkl"); fs12E = best_score(fs12,12); fs12E['sympy_format']
# Out:
# 0.48965084651516*exp(-9.430363e-8*Cum_N)

# %%
fs12MB = fs12.get_best(); fs12MB['sympy_format']
# Out:
# 0.489610926908988*exp(-9.525791e-8*Cum_N) + 0.0013130757/(-Cum_N + Cum_N/Ring + 0.326058685)

# %%
fs12E['features'] = r"$N_C$"; fs12MB['features'] = r"$N_C,Ring$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/77473854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs12E['features'] = r"$N_C$"; fs12MB['features'] = r"$N_C,Ring$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/77473854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs12E['features'] = r"$N_C$"; fs12MB['features'] = r"$N_C,Ring$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/77473854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fs12.equations_['complexity'],fs12.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("Feature Set 12 Equations")
axT = ax.twinx()
axT.plot(fs12.equations_['complexity'],fs12.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # All Features Used

# %%
fsTD = pickle_load("../Scripts/DIFF/DIFF_TD.pkl"); fsTDE = best_score(fsTD,100); fsTDE['sympy_format']
# Out:
# 0.489633806962191*exp(-9.428389e-8*Cum_N)

# %%
fsTDMB = fsTD.get_best(); fsTDMB['sympy_format']
# Out:
# -Pop*(8.4170544e-8*Nbar - 8.4170544e-8*Pop)/(Cum_N + Cum_Nbar) + 0.489508574652265*exp(-9.566675e-8*Cum_N)

# %%
fsTDE['features'] = r"$N_C$"; fsTDMB['features'] = r"$N,\bar{N},N_C,\bar{N}_C$"
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2917028823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fsTDE['features'] = r"$N_C$"; fsTDMB['features'] = r"$N,\bar{N},N_C,\bar{N}_C$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2917028823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fsTDE['features'] = r"$N_C$"; fsTDMB['features'] = r"$N,\bar{N},N_C,\bar{N}_C$"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/2917028823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.plot(fsTD.equations_['complexity'],fsTD.equations_['loss'],'-o',alpha=0.7, label = "Loss")
ax.set_title("All Features Equations")
axT = ax.twinx()
axT.plot(fsTD.equations_['complexity'],fsTD.equations_['score'],'-o',c='r',alpha=0.7, label = "Score")
fig.legend()
ax.set_xlabel("Complexity"); ax.set_ylabel("Loss"); axT.set_ylabel("Score")
fig.tight_layout; plt.show()

# %% [markdown]
# # Model Comparison

# %%
def Null_Model_Errors(true,mean):
    errs = np.zeros(true.shape)
    for i in range(true.shape[1]):
        for j in range(true.shape[2]):
            errs[:,i,j] = np.sqrt(np.square(mean-true[:,i,j]))
    return errs

# %%
def get_errors(true, preds, agg="None"):
    rows,cols,points = true.shape[0],true.shape[1],true.shape[2]
    rmse = np.sqrt(np.square(preds-true))
    if agg=="None": return rmse
    if agg=="Time": return rmse.mean(axis=(1,2))
    if agg=="Space": return rmse.mean(axis=0)
    else: return "Invalid Agg"

# %%
def predict(equation,dataframes):
    rows = len(dataframes); cols = len(dataframes[0]); points = len(dataframes[0][0])
    preds = np.zeros((points,rows,cols))
    for i in range(rows):
        for df in dataframes[i]:
            ii = int(df['i'][0]); jj = int(df['j'][0])
            preds[:,ii,jj] = np.array(df.eval(equation))
    return preds

# %%
time = np.arange(N_D.shape[1]) * 0.1
dNdt = hlp.cubic_splines(N_D[1],time); dNovN = dNdt / N_D[1]
true = dNovN
mean = np.mean(dNovN,axis=(1,2))

# %%
model_list = [fs1MB,fs1E,fs2MB,fs2E,fs3MB,fs3E,fs4MB,fs4E,fs5MB,fs5E,
              fs9MB,fs9E,fs10MB,fs10E,fs11MB,fs11E,fs12MB,fs12E,fsTDMB,fsTDE,fs10HP]

model_errors = {"MB1":[0],"BS1":[1],"MB2":[2],"BS2":[3],"MB3":[4],"BS3":[5],
                "MB4":[6],"BS4":[7],"MB5":[8],"BS5":[9],"MB9":[10],"BS9":[11],
                "MB10":[12],"BS10":[13],"MB11":[14],"BS11":[15],"MB12":[16],"BS12":[17],
                "MBTD":[18],"BSTD":[19],"HP10":[20]}

for model in model_errors:
    preds = predict(model_list[model_errors[model][0]]['equation'],DIFF_DF[0][1])
    model_errors[model].append(get_errors(true,preds,agg="Space"))

null_error = Null_Model_Errors(true,mean).mean(axis=0)

# %%
BSEQs = pd.concat([fs1E,fs2E,fs3E,fs4E,fs5E,fs9E,fs10E,fs11E,fs12E,fsTDE],axis=1).T; BSEQs.reset_index(drop=True, inplace= True)
MBEQs = pd.concat([fs1MB,fs2MB,fs3MB,fs4MB,fs5MB,fs9MB,fs10MB,fs11MB,fs12MB,fsTDMB],axis=1).T; 
MBEQs.reset_index(drop=True, inplace= True)
BSEQs["Type"] = "Best Score"
MBEQs["Type"] = "Model Best"
HPEQ = fs10HP; HPEQ["Type"] = "Hand Pick"
BEQs = pd.concat([BSEQs,MBEQs],axis=0); BEQs.reset_index(drop=True, inplace=True);
BEQs = pd.concat([BEQs,pd.DataFrame(HPEQ).T],axis=0); BEQs.reset_index(drop=True, inplace=True)
# Out:
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3640287615.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HPEQ = fs10HP; HPEQ["Type"] = "Hand Pick"
# /run/nvme/job_17175884/tmp/ipykernel_1744690/3640287615.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HPEQ = fs10HP; HPEQ["Type"] = "Hand Pick"

# %%
fig, ax = plt.subplots()
inds = [5,15,18,16,19,20]
BEQSP = BEQs.iloc[inds]
noise = np.random.normal(0,0.05,len(BEQSP))
sns.scatterplot(data=BEQSP, x=BEQSP['complexity']+noise, y='loss', hue='features', style='Type',s=150, ax=ax)
sns.move_legend(ax, bbox_to_anchor=(1, 0.5), loc='center left')
ax.set_axisbelow(True)
ax.grid(color='gray', linestyle='dashed')
ax.set_title("Diffusion Model Comparison")
ax.set_ylabel("training loss")
plt.show()

# %%
fig, axs = plt.subplots(2,2,figsize=(12,8))

cmax = np.max(null_error)

p1 = axs[0,0].imshow(null_error, cmap = 'Reds', vmin=0,vmax=cmax); axs[0,0].set_title(r"Null")
p2 = axs[0,1].imshow(model_errors['MB9'][1], cmap = 'Reds', vmin=0,vmax=cmax); axs[0,1].set_title(r"$N_C$, Complexity=6")
p3 = axs[1,0].imshow(model_errors['HP10'][1], cmap = 'Reds', vmin=0,vmax=cmax); axs[1,0].set_title(r"$N_C,\bar{N}_C$, Complexity=13")
p3 = axs[1,1].imshow(model_errors['MB10'][1], cmap = 'Reds', vmin=0,vmax=cmax); 
axs[1,1].set_title(model_list[model_errors['MB10'][0]]['features']+r", Complexity=18")

for ax in axs.ravel():
    ax.set_xticks([]);ax.set_yticks([])
    
fig.colorbar(p1,ax=axs,fraction=0.046*.67, pad=0.04)
fig.suptitle("Diffusion Model Errors")
plt.show()

# %%
from sympy import latex
ind = model_errors['MB10'][0]; latex(model_list[ind]['sympy_format'])
# Out:
# '\\frac{0.019496204 Cum_{N} - 0.019496204 Cum_{\\bar{N}}}{Cum_{\\bar{N}} + 805184.378971702} + 0.489650895480247 e^{- 9.511543 \\cdot 10^{-8} Cum_{N}}'

# %%
model_list[ind]['equation']
# Out:
# '(exp((-9.511543e-8 * Cum_N) + -0.7140626) + ((-0.019496204 * (Cum_Nbar - Cum_N)) / (Cum_Nbar + (-0.078773394 / -9.783274e-8))))'

# %% [markdown]
# # Interpreting the Equation

# %%
HPeq10 = '(np.exp((-9.511543e-8 * Cum_N) + -0.7169847) + np.exp((Cum_Nbar / -0.12202544) / Cum_N))'

# %%
MBeq10 = '(np.exp((-9.511543e-8 * Cum_N) + -0.7140626) + ((-0.019496204 * (Cum_Nbar - Cum_N)) / (Cum_Nbar + (-0.078773394 / -9.783274e-8))))'

# %%
mx1 = 0; mx2 = 0;
for row in DIFF_DF[0][1]:
    for df in row:
        val1 = df['Cum_N'].max()
        val2 = df['Cum_Nbar'].max()
        if val1 > mx1: mx1 = val1
        if val2 > mx2: mx2 = val2
print(mx1,mx2)
# Out:
# 273645706.6208211 203509599.40414286

# %%
mn1 = mx1; mn2 = mx2;
for row in DIFF_DF[0][1]:
    for df in row:
        val1 = df['Cum_N'].min()
        val2 = df['Cum_Nbar'].min()
        if val1 < mn1: mn1 = val1
        if val2 < mn2: mn2 = val2
print(mn1,mn2)
# Out:
# 1503.987819272313 1572.7940800239198

# %%
x = np.linspace(mn1-10,mx1+5e7,1000)
y = np.linspace(mn1-10,mx1-5e7,1000)
Cum_N, Cum_Nbar = np.meshgrid(x,y)
preds = eval(HPeq10,None,{"Cum_N":Cum_N,"Cum_Nbar":Cum_Nbar})
preds2 = eval(MBeq10,None,{"Cum_N":Cum_N,"Cum_Nbar":Cum_Nbar})

# %%
import matplotlib.colors as colors

fig, axs = plt.subplots(figsize=(8,6))

hm = axs.pcolor(Cum_N,Cum_Nbar,preds,
           norm=colors.LogNorm(vmin=np.min(preds), vmax=np.max(preds)),cmap="YlGn"
          )
#hm2 = axs[1].pcolor(Cum_N,Cum_Nbar,preds2,
          # norm=colors.LogNorm(vmin=np.min(np.abs(preds2)), vmax=np.max(preds2)),cmap="YlGn")
                   
#plt.colorbar()
#cp = ax.contour(Cum_N,Cum_Nbar,preds, levels = [-0.01,-0.001,0,0.001,.01],linestyles='dashed',linewidths=2)

colony_traces = [(0,0),(9,9),(31,47),(1,1),(10,0)]
c = DIFF_DF[0][1][0][0]["time"].values

#for ax in axs:
for (i,j) in colony_traces:
    trace = DIFF_DF[0][1][i][j]
    scat = axs.scatter(trace['Cum_N'],trace['Cum_Nbar'],c=c,cmap="RdBu",s=10)
    x,y = scat.get_offsets()[-1]
    if (i,j) == (0,0): axs.annotate(f"{(i,j)}", xy=(x,y+8e6),fontsize=8)
    else: axs.annotate(f"{(i,j)}", xy=(x+8e6,y+8e6),fontsize=8)


#fig.supxlabel("Cumulative Population")
#fig.supylabel("Cumulative Avg. Neighbor Population")
axs.set_xlabel(r"$N_C$"); axs.set_ylabel(r"$\bar{N}_C$")
axs.set_title(r"$\frac{dN}{dt\cdot N} = f(N_C,\bar{N}_C)$")
#axs[1].set_title(r"$\frac{dN}{dt\cdot N} = f_2(N_C,\bar{N}_C)$")
fig.tight_layout()
fig.colorbar(hm,ax=axs)
plt.show()

# %%
import matplotlib.colors as colors

fig, axs = plt.subplots(figsize=(8,6))

#hm = axs.pcolor(Cum_N,Cum_Nbar,preds,
 #          norm=colors.LogNorm(vmin=np.min(preds), vmax=np.max(preds)),cmap="YlGn"
  #        )
hm = axs.pcolor(Cum_N,Cum_Nbar,preds2,
          norm=colors.LogNorm(vmin=np.min(np.abs(preds2)), vmax=np.max(preds2)),cmap="YlGn")
                   
#plt.colorbar()
#cp = ax.contour(Cum_N,Cum_Nbar,preds, levels = [-0.01,-0.001,0,0.001,.01],linestyles='dashed',linewidths=2)

colony_traces = [(0,0),(9,9),(31,47),(1,1),(10,0)]
c = DIFF_DF[0][1][0][0]["time"].values

#for ax in axs:
for (i,j) in colony_traces:
    trace = DIFF_DF[0][1][i][j]
    scat = axs.scatter(trace['Cum_N'],trace['Cum_Nbar'],c=c,cmap="RdBu",s=10)
    x,y = scat.get_offsets()[-1]
    if (i,j) == (0,0): axs.annotate(f"{(i,j)}", xy=(x,y+8e6),fontsize=8)
    else: axs.annotate(f"{(i,j)}", xy=(x+8e6,y+8e6),fontsize=8)


#fig.supxlabel("Cumulative Population")
#fig.supylabel("Cumulative Avg. Neighbor Population")
axs.set_xlabel(r"$N_C$"); axs.set_ylabel(r"$\bar{N}_C$")
axs.set_title(r"$\frac{dN}{dt\cdot N} = f(N_C,\bar{N}_C)$")
#axs[1].set_title(r"$\frac{dN}{dt\cdot N} = f_2(N_C,\bar{N}_C)$")
fig.tight_layout()
fig.colorbar(hm,ax=axs)
plt.show()

# %%
dNovN.shape
# Out:
# (400, 32, 48)

# %%
preds = predict(model_list[model_errors["MB10"][0]]['equation'],DIFF_DF[0][1])
plt.plot(dNovN[:,0,0],label="real")
plt.plot(preds[:,0,0],label="predicted")
plt.plot()
plt.legend()
plt.show()

# %%
np.where(preds < 0)
# Out:
# (array([198, 198, 199, ..., 399, 399, 399]),
#  array([13, 14, 13, ..., 30, 30, 30]),
#  array([33, 46, 33, ..., 44, 45, 46]))

# %%
S_D.shape
# Out:
# (4, 400, 32, 48)

# %%
for i in range(32):
    for j in range(48):
        plt.plot(S_D[1,:,i,j])

plt.show()

# %%
plt.plot(S_D[1,:,0,0],label="0,0")
plt.plot(S_D[1,:,10,0],label="10,0")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots()
a = axs.imshow(S_D[1,399,:,:],cmap="Blues")
fig.colorbar(a)
plt.show()
